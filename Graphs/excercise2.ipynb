# %%
from typing import TypedDict, List
from langgraph.graph import StateGraph , START , END

# %%
class AgentState(TypedDict):
    name: str
    values: List[int]
    operation: str
    result: str

# %%
def calculate_node(state: AgentState) -> AgentState:
    """single node that adds or multiplies values based on the operation specified in the state"""
    if state['operation'] == "+":
        state['result'] = f"hi there  {state['name']}! your sum = {sum(state['values'])}"
    elif state['operation'] == '*':
        product = 1
        for value in state['values']:
            product *= value
        state['result'] = f"hi there  {state['name']}! your product = {product}"
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("calculator", calculate_node)
graph.add_edge(START, "calculator")
graph.add_edge("calculator", END)

app = graph.compile()

# %%
result = app.invoke({
    "name": "Alice",
    "values": [1,2,3],
    "operation": "*",
})

# %%
print(result['result'])
# Out:
# hi there  Alice! your product = 6
